# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from statsmodels.formula.api import ols
import statsmodels.api as sm

import fair_var

# %%
data = pd.read_csv("../data/chirper-happiness.csv")

# %% [markdown]
# # Explore Data

# %%
data
# Out:
#              Id2  totalGroup1  totalGroup2  percent_bachelorPlus  meanvalence  \
# 0     6037101110         1244         2319                  19.4     5.863903
# 1     6037101122          304         2175                  27.2     5.963174
# 2     6037101210         2434         2078                  16.6     5.623312
# 3     6037101220          509         1370                  19.8     5.687386
# 4     6037101300          365         3116                  31.0     5.687331
# ...          ...          ...          ...                   ...          ...
# 2105  6037920338          738         2728                  59.8     5.877809
# 2106  6037920339          808         3367                  55.5     5.888279
# 2107  6037930101           27           98                  64.9     5.713390
# 2108  6037930200          117          240                  30.6     5.820676
# 2109  6037930301          147          545                  15.7     5.811784
#
#       households_meanIncome
# 0                     68938
# 1                    120490
# 2                     54481
# 3                     51880
# 4                     90933
# ...                     ...
# 2105                 177556
# 2106                 162243
# 2107                  61578
# 2108                 117289
# 2109                  76920
#
# [2110 rows x 6 columns]

# %%
plt.hist(data["meanvalence"])
# Out:
# (array([1.000e+00, 5.000e+00, 1.040e+02, 1.108e+03, 7.890e+02, 9.800e+01,
#         4.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([5.11      , 5.29313889, 5.47627778, 5.65941667, 5.84255556,
#         6.02569444, 6.20883333, 6.39197222, 6.57511111, 6.75825   ,
#         6.94138889]),
#  <a list of 10 Patch objects>)

# %%
data["meanvalence"].mean()
# Out:
# 5.828721131636487

# %% [markdown]
# # 1. Ground Truth Model

# %%
data = data.drop("Id2", axis = 1)

# %%
## correlation
data.corr()
# Out:
#                        totalGroup1  totalGroup2  percent_bachelorPlus  \
# totalGroup1               1.000000    -0.503950             -0.729305
# totalGroup2              -0.503950     1.000000              0.726215
# percent_bachelorPlus     -0.729305     0.726215              1.000000
# meanvalence              -0.361185     0.335692              0.457267
# households_meanIncome    -0.507290     0.585684              0.752844
#
#                        meanvalence  households_meanIncome
# totalGroup1              -0.361185              -0.507290
# totalGroup2               0.335692               0.585684
# percent_bachelorPlus      0.457267               0.752844
# meanvalence               1.000000               0.311013
# households_meanIncome     0.311013               1.000000

# %%
sns.heatmap(data.corr(), cmap= 'coolwarm')

# %% [markdown]
# # Ground Truth Model

# %%
plt.figure(figsize=(20,10))
plt.subplot(2, 2, 1)
plt.scatter(data["percent_bachelorPlus"], data["meanvalence"], c = data["totalGroup1"], cmap = 'viridis')
plt.xlabel("percent_bachelorPlus")
plt.ylabel("meanvalence")
plt.title("Color totalGroup1")
plt.colorbar()

plt.subplot(2,2,2)
plt.scatter(data["percent_bachelorPlus"], data["meanvalence"], c = data["totalGroup2"], cmap = 'viridis')
plt.xlabel("percent_bachelorPlus")
plt.ylabel("meanvalence")
plt.title("Color totalGroup2")
plt.colorbar()


plt.subplot(2, 2, 3)
plt.scatter(data["households_meanIncome"], data["meanvalence"], c = data["totalGroup1"], cmap = 'viridis')
plt.xlabel("households_meanIncome")
plt.ylabel("meanvalence")
plt.title("Color totalGroup1")
plt.colorbar()

plt.subplot(2,2,4)
plt.scatter(data["households_meanIncome"], data["meanvalence"], c = data["totalGroup2"], cmap = 'viridis')
plt.xlabel("households_meanIncome")
plt.ylabel("meanvalence")
plt.title("Color totalGroup2")
plt.colorbar()

plt.tight_layout()

# %%
## remove some outliers to scale down
data = data[data["meanvalence"]<6.7][data["meanvalence"]>5.2]
# Out:
# /opt/anaconda3/envs/jaeyoung/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
plt.figure(figsize=(20,10))
plt.subplot(2, 2, 1)
plt.scatter(data["percent_bachelorPlus"], data["meanvalence"], c = data["totalGroup1"], cmap = 'viridis')
plt.xlabel("percent_bachelorPlus")
plt.ylabel("meanvalence")
plt.title("Color totalGroup1")
plt.colorbar()

plt.subplot(2,2,2)
plt.scatter(data["percent_bachelorPlus"], data["meanvalence"], c = data["totalGroup2"], cmap = 'viridis')
plt.xlabel("percent_bachelorPlus")
plt.ylabel("meanvalence")
plt.title("Color totalGroup2")
plt.colorbar()


plt.subplot(2, 2, 3)
plt.scatter(data["households_meanIncome"], data["meanvalence"], c = data["totalGroup1"], cmap = 'viridis')
plt.xlabel("households_meanIncome")
plt.ylabel("meanvalence")
plt.title("Color totalGroup1")
plt.colorbar()

plt.subplot(2,2,4)
plt.scatter(data["households_meanIncome"], data["meanvalence"], c = data["totalGroup2"], cmap = 'viridis')
plt.xlabel("households_meanIncome")
plt.ylabel("meanvalence")
plt.title("Color totalGroup2")
plt.colorbar()

plt.tight_layout()

# %% [markdown]
# Color distribution is different. ==> There is bias based on ethnic groups.

# %% [markdown]
# # 2. Ethnic Group Aware Model

# %%
X = data.drop(['meanvalence'], axis=1)
y = data["meanvalence"]
X = sm.add_constant(X)

# %%
## train_test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=1)

# %%
## linear regression model
linreg = sm.OLS(y_train, X_train).fit()
print(linreg.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            meanvalence   R-squared:                       0.234
# Model:                            OLS   Adj. R-squared:                  0.232
# Method:                 Least Squares   F-statistic:                     128.3
# Date:                Wed, 24 Mar 2021   Prob (F-statistic):           1.04e-95
# Time:                        13:29:06   Log-Likelihood:                 1582.8
# No. Observations:                1686   AIC:                            -3156.
# Df Residuals:                    1681   BIC:                            -3128.
# Df Model:                           4
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     5.7756      0.010    605.819      0.000       5.757       5.794
# totalGroup1           -5.967e-06    3.1e-06     -1.923      0.055   -1.21e-05     1.2e-07
# totalGroup2           -1.197e-06   3.37e-06     -0.355      0.722   -7.81e-06    5.41e-06
# percent_bachelorPlus      0.0025      0.000     10.414      0.000       0.002       0.003
# households_meanIncome -1.321e-07   8.19e-08     -1.613      0.107   -2.93e-07    2.85e-08
# ==============================================================================
# Omnibus:                       57.144   Durbin-Watson:                   2.056
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              128.241
# Skew:                           0.172   Prob(JB):                     1.42e-28
# Kurtosis:                       4.307   Cond. No.                     3.68e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.68e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
data["ypred"] = linreg.predict(X)

# %%
## Plot Ethnic Group Aware Model
plt.figure(figsize=(20,10))
plt.subplot(2, 2, 1)
plt.scatter(data["percent_bachelorPlus"], data["ypred"], c = data["totalGroup1"], cmap = 'viridis')
plt.xlabel("percent_bachelorPlus")
plt.ylabel("Predicted Valence")
plt.title("Color totalGroup1")
plt.axhline(y=5.8, color='r', linestyle='-')
plt.colorbar()

plt.subplot(2,2,2)
plt.scatter(data["percent_bachelorPlus"], data["ypred"], c = data["totalGroup2"], cmap = 'viridis')
plt.xlabel("percent_bachelorPlus")
plt.ylabel("Predicted Valence")
plt.title("Color totalGroup2")
plt.axhline(y=5.8, color='r', linestyle='-')
plt.colorbar()


plt.subplot(2, 2, 3)
plt.scatter(data["households_meanIncome"], data["ypred"], c = data["totalGroup1"], cmap = 'viridis')
plt.xlabel("households_meanIncome")
plt.ylabel("meanvalence")
plt.title("Color totalGroup1")
plt.axhline(y=5.8, color='r', linestyle='-')
plt.colorbar()

plt.subplot(2,2,4)
plt.scatter(data["households_meanIncome"], data["ypred"], c = data["totalGroup2"], cmap = 'viridis')
plt.xlabel("households_meanIncome")
plt.ylabel("Predicted Valence")
plt.title("Color totalGroup2")
plt.axhline(y=5.8, color='r', linestyle='-')
plt.colorbar()
plt.tight_layout()

# %%
## splitted plot based on y_pred 5.8
data1 = data[data["ypred"]<5.8]
data2 = data[data["ypred"]>=5.8]

plt.figure(figsize=(20,10))
plt.subplot(2, 4, 1)
plt.scatter(data1["percent_bachelorPlus"], data1["ypred"], c = data1["totalGroup1"], cmap = 'viridis')
plt.xlabel("percent_bachelorPlus")
plt.ylabel("Predicted Valence")
plt.title("Color totalGroup1 for ypred<5.8")
plt.colorbar()

plt.subplot(2,4,2)
plt.scatter(data1["percent_bachelorPlus"], data1["ypred"], c = data1["totalGroup2"], cmap = 'viridis')
plt.xlabel("percent_bachelorPlus")
plt.ylabel("Predicted Valence")
plt.title("Color totalGroup2 for ypred<5.8")
plt.colorbar()


plt.subplot(2, 4, 3)
plt.scatter(data1["households_meanIncome"], data1["ypred"], c = data1["totalGroup1"], cmap = 'viridis')
plt.xlabel("households_meanIncome")
plt.ylabel("meanvalence")
plt.title("Color totalGroup1 for ypred<5.8")
plt.colorbar()

plt.subplot(2,4,4)
plt.scatter(data1["households_meanIncome"], data1["ypred"], c = data1["totalGroup2"], cmap = 'viridis')
plt.xlabel("households_meanIncome")
plt.ylabel("Predicted Valence")
plt.title("Color totalGroup2 for ypred<5.8")
plt.colorbar()


plt.subplot(2, 4, 5)
plt.scatter(data2["percent_bachelorPlus"], data2["ypred"], c = data2["totalGroup1"], cmap = 'viridis')
plt.xlabel("percent_bachelorPlus")
plt.ylabel("Predicted Valence")
plt.title("Color totalGroup1 for ypred>=5.8")
plt.colorbar()

plt.subplot(2,4,6)
plt.scatter(data2["percent_bachelorPlus"], data2["ypred"], c = data2["totalGroup2"], cmap = 'viridis')
plt.xlabel("percent_bachelorPlus")
plt.ylabel("Predicted Valence")
plt.title("Color totalGroup2 for ypred>=5.8")
plt.colorbar()


plt.subplot(2, 4, 7)
plt.scatter(data2["households_meanIncome"], data2["ypred"], c = data2["totalGroup1"], cmap = 'viridis')
plt.xlabel("households_meanIncome")
plt.ylabel("meanvalence")
plt.title("Color totalGroup1 for ypred>=5.8")
plt.colorbar()

plt.subplot(2,4,8)
plt.scatter(data2["households_meanIncome"], data2["ypred"], c = data2["totalGroup2"], cmap = 'viridis')
plt.xlabel("households_meanIncome")
plt.ylabel("Predicted Valence")
plt.title("Color totalGroup2 for ypred>=5.8")
plt.colorbar()


plt.tight_layout()

# %% [markdown]
# ## Correlation, Heatmap

# %%
cor_data = data[["totalGroup1", "totalGroup2", "percent_bachelorPlus", "households_meanIncome", "ypred"]]

# %%
cor_data.corr()
# Out:
#                        totalGroup1  totalGroup2  percent_bachelorPlus  \
# totalGroup1               1.000000    -0.504204             -0.730026
# totalGroup2              -0.504204     1.000000              0.726248
# percent_bachelorPlus     -0.730026     0.726248              1.000000
# households_meanIncome    -0.507632     0.585690              0.752866
# ypred                    -0.788278     0.702915              0.992926
#
#                        households_meanIncome     ypred
# totalGroup1                        -0.507632 -0.788278
# totalGroup2                         0.585690  0.702915
# percent_bachelorPlus                0.752866  0.992926
# households_meanIncome               1.000000  0.694373
# ypred                               0.694373  1.000000

# %%
sns.heatmap(cor_data.corr(), cmap= 'coolwarm')

# %%
X = data.drop(['meanvalence'], axis=1)
y = data["meanvalence"]

# %% [markdown]
# # 3. Ethnic Group Blind Model

# %%
X = data.drop(['meanvalence', 'totalGroup1', 'totalGroup2', "ypred"], axis=1)
y = data["meanvalence"]
X = sm.add_constant(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=1)

# %%
linreg = sm.OLS(y_train, X_train).fit()
print(linreg.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            meanvalence   R-squared:                       0.232
# Model:                            OLS   Adj. R-squared:                  0.231
# Method:                 Least Squares   F-statistic:                     254.5
# Date:                Mon, 22 Mar 2021   Prob (F-statistic):           2.81e-97
# Time:                        22:04:54   Log-Likelihood:                 1580.9
# No. Observations:                1686   AIC:                            -3156.
# Df Residuals:                    1683   BIC:                            -3139.
# Df Model:                           2
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     5.7599      0.005   1204.254      0.000       5.750       5.769
# percent_bachelorPlus      0.0028      0.000     16.182      0.000       0.002       0.003
# households_meanIncome -1.477e-07   8.15e-08     -1.813      0.070   -3.07e-07    1.21e-08
# ==============================================================================
# Omnibus:                       59.873   Durbin-Watson:                   2.054
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              131.698
# Skew:                           0.196   Prob(JB):                     2.52e-29
# Kurtosis:                       4.312   Cond. No.                     1.84e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.84e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
data["ypred"] = linreg.predict(X)

# %%
## Plot Ethnic Group Blind Model
plt.figure(figsize=(20,10))
plt.subplot(2, 2, 1)
plt.scatter(data["percent_bachelorPlus"], data["ypred"], c = data["totalGroup1"], cmap = 'viridis')
plt.xlabel("percent_bachelorPlus")
plt.ylabel("Predicted Valence")
plt.title("Color totalGroup1")
plt.axhline(y=5.8, color='r', linestyle='-')
plt.colorbar()

plt.subplot(2,2,2)
plt.scatter(data["percent_bachelorPlus"], data["ypred"], c = data["totalGroup2"], cmap = 'viridis')
plt.xlabel("percent_bachelorPlus")
plt.ylabel("Predicted Valence")
plt.title("Color totalGroup2")
plt.axhline(y=5.8, color='r', linestyle='-')
plt.colorbar()


plt.subplot(2, 2, 3)
plt.scatter(data["households_meanIncome"], data["ypred"], c = data["totalGroup1"], cmap = 'viridis')
plt.xlabel("households_meanIncome")
plt.ylabel("meanvalence")
plt.title("Color totalGroup1")
plt.axhline(y=5.8, color='r', linestyle='-')
plt.colorbar()

plt.subplot(2,2,4)
plt.scatter(data["households_meanIncome"], data["ypred"], c = data["totalGroup2"], cmap = 'viridis')
plt.xlabel("households_meanIncome")
plt.ylabel("Predicted Valence")
plt.title("Color totalGroup2")
plt.axhline(y=5.8, color='r', linestyle='-')
plt.colorbar()

plt.tight_layout()

# %%
cor_data = data[["totalGroup1", "totalGroup2", "percent_bachelorPlus", "households_meanIncome", "ypred"]]

# %%
cor_data.corr()
# Out:
#                        totalGroup1  totalGroup2  percent_bachelorPlus  \
# totalGroup1               1.000000    -0.504204             -0.730026
# totalGroup2              -0.504204     1.000000              0.726248
# percent_bachelorPlus     -0.730026     0.726248              1.000000
# households_meanIncome    -0.507632     0.585690              0.752866
# ypred                    -0.732789     0.719168              0.996780
#
#                        households_meanIncome     ypred
# totalGroup1                        -0.507632 -0.732789
# totalGroup2                         0.585690  0.719168
# percent_bachelorPlus                0.752866  0.996780
# households_meanIncome               1.000000  0.697667
# ypred                               0.697667  1.000000

# %%
sns.heatmap(cor_data.corr(), cmap= 'coolwarm')

# %% [markdown]
# # 4. Fair Model

# %%
## used first function of fair_var.py
data["meanvalence_fair"] = fair_var.gen_latent_fast(data.loc[:, data.columns != "Id2"], ["totalGroup1", "totalGroup2"], "meanvalence" )

# %%
## Plot Fair Model
plt.figure(figsize=(20,10))
plt.subplot(2, 2, 1)
plt.scatter(data["percent_bachelorPlus"], data["meanvalence_fair"], c = data["totalGroup1"], cmap = 'viridis')
plt.xlabel("percent_bachelorPlus")
plt.ylabel("Predicted Valence")
plt.title("Color totalGroup1")
plt.axhline(y=0, color='r', linestyle='-')
plt.colorbar()

plt.subplot(2,2,2)
plt.scatter(data["percent_bachelorPlus"], data["meanvalence_fair"], c = data["totalGroup2"], cmap = 'viridis')
plt.xlabel("percent_bachelorPlus")
plt.ylabel("Predicted Valence")
plt.title("Color totalGroup2")
plt.axhline(y=0, color='r', linestyle='-')
plt.colorbar()


plt.subplot(2, 2, 3)
plt.scatter(data["households_meanIncome"], data["meanvalence_fair"], c = data["totalGroup1"], cmap = 'viridis')
plt.xlabel("households_meanIncome")
plt.ylabel("meanvalence")
plt.title("Color totalGroup1")
plt.axhline(y=0, color='r', linestyle='-')
plt.colorbar()

plt.subplot(2,2,4)
plt.scatter(data["households_meanIncome"], data["meanvalence_fair"], c = data["totalGroup2"], cmap = 'viridis')
plt.xlabel("households_meanIncome")
plt.ylabel("Predicted Valence")
plt.title("Color totalGroup2")
plt.axhline(y=0, color='r', linestyle='-')
plt.colorbar()

plt.tight_layout()

# %%
## used second function of fair_var.py with lbd = 0 ==> Completely fair var
data["meanvalence_fair"] = fair_var.gen_latent_nonparam_regula(data.loc[:, data.columns != "Id2"], ["totalGroup1", "totalGroup2"], "meanvalence" , lbd =0)

# %%
## Plot Fair Model
plt.figure(figsize=(20,10))
plt.subplot(2, 2, 1)
plt.scatter(data["percent_bachelorPlus"], data["meanvalence_fair"], c = data["totalGroup1"], cmap = 'viridis')
plt.xlabel("percent_bachelorPlus")
plt.ylabel("Predicted Valence")
plt.title("Color totalGroup1")
plt.axhline(y=0, color='r', linestyle='-')
plt.colorbar()

plt.subplot(2,2,2)
plt.scatter(data["percent_bachelorPlus"], data["meanvalence_fair"], c = data["totalGroup2"], cmap = 'viridis')
plt.xlabel("percent_bachelorPlus")
plt.ylabel("Predicted Valence")
plt.title("Color totalGroup2")
plt.axhline(y=0, color='r', linestyle='-')
plt.colorbar()


plt.subplot(2, 2, 3)
plt.scatter(data["households_meanIncome"], data["meanvalence_fair"], c = data["totalGroup1"], cmap = 'viridis')
plt.xlabel("households_meanIncome")
plt.ylabel("meanvalence")
plt.title("Color totalGroup1")
plt.axhline(y=0, color='r', linestyle='-')
plt.colorbar()

plt.subplot(2,2,4)
plt.scatter(data["households_meanIncome"], data["meanvalence_fair"], c = data["totalGroup2"], cmap = 'viridis')
plt.xlabel("households_meanIncome")
plt.ylabel("Predicted Valence")
plt.title("Color totalGroup2")
plt.axhline(y=0, color='r', linestyle='-')
plt.colorbar()

plt.tight_layout()

# %%
## symmetry based on y = 0

# %%
cor_data = data[["totalGroup1", "totalGroup2", "percent_bachelorPlus", "households_meanIncome", "meanvalence_fair"]]

# %%
cor_data.corr()
# Out:
#                         totalGroup1   totalGroup2  percent_bachelorPlus  \
# totalGroup1            1.000000e+00 -5.042040e-01             -0.730026
# totalGroup2           -5.042040e-01  1.000000e+00              0.726248
# percent_bachelorPlus  -7.300259e-01  7.262483e-01              1.000000
# households_meanIncome -5.076321e-01  5.856899e-01              0.752866
# meanvalence_fair       1.299021e-16  6.410078e-18              0.138594
#
#                        households_meanIncome  meanvalence_fair
# totalGroup1                        -0.507632      1.299021e-16
# totalGroup2                         0.585690      6.410078e-18
# percent_bachelorPlus                0.752866      1.385941e-01
# households_meanIncome               1.000000      6.976816e-02
# meanvalence_fair                    0.069768      1.000000e+00

# %%
sns.heatmap(cor_data.corr(), cmap= 'coolwarm')

# %%
## different from the previous heatmaps. Meanvalence_fair has almost no correlation between other features.
