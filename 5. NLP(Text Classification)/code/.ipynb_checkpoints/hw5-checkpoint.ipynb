# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize  
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.porter import *
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, f1_score, recall_score
from sklearn.feature_extraction.text import CountVectorizer
    
import re
import collections
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/jaeyoungkim/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/jaeyoungkim/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jaeyoungkim/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
labels  = pd.read_csv("../data/ps5_tweets_labels.csv")
number_labels  = pd.read_csv("../data/ps5_tweets_labels_as_numbers.csv")
text  = pd.read_csv("../data/ps5_tweets_text.csv")

# %% [markdown]
# # Preprocessing

# %%
text = text.merge(number_labels, left_on = "Id", right_on = "Id")

# %%
text
# Out:
#           Id                                              Tweet  Label
# 0          0  https://t.co/UpjxfOgQs8\r\r\n\r\r\nGaisss! Ple...      4
# 1          1  @mygovindia Today just after a week of lockdow...      1
# 2          2  Tuskys partners with Amref to provide on groun...      2
# 3          3  @chrissyteigen are u doing ur own grocery shop...      1
# 4          4  UK Critical Care Nurse Cries at Empty SuperMar...      0
# ...      ...                                                ...    ...
# 37036  37036  Minnesota classifies grocery store workers as ...      1
# 37037  37037  US Senator @ewarren has asked for information ...      1
# 37038  37038  Just commented on @thejournal_ie: Poll: Are yo...      0
# 37039  37039  My wife got laid off yesterday because the sma...      2
# 37040  37040  Humanity is doomed\r\r\n#coronavirus #coronacr...      0
#
# [37041 rows x 3 columns]

# %%
import re
import string

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import TweetTokenizer

from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
tokenizer = TweetTokenizer(preserve_case = False, strip_handles = True, reduce_len = True)
nltk.download('stopwords')
stopwords_english = stopwords.words('english')
punctuations = string.punctuation
stemmer = PorterStemmer()

def text_normalizer(text):
    
    ## remove special characters
    text = re.sub(r'^RT[\s]+', '', text)
    text = re.sub(r'https?:\/\/.*[\r\n]*', '', text)
    text = re.sub(r'#', '', text)
    
    
    ## remove stopwords and punctuations
    text = tokenizer.tokenize(text)
    res = []
    for word in text:
        if word not in stopwords_english and word not in punctuations:
            res.append(word)
    
    stem_res = []
    ## stemming
    for word in res:
        stem = stemmer.stem(word)
        stem_res.append(stem)
        
        
    return stem_res
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jaeyoungkim/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print("Original Text : ", text.iloc[5300]["Tweet"])
print("###################################")
print("Normalized Text : ", text_normalizer(text.iloc[5300]["Tweet"]))
# Out:
# Original Text :  Alert: Largest wholesale and retail Ongata Rongai Kware Open Air Market faces imminent closure this day in a mid to combat covid 19 spread. This move will leave consumers at the mercy of local retailers who will enjoy freedom of setting prices.
# Be on the lookout!
# #GikombaCorona
# ###################################
# Normalized Text :  ['alert', 'largest', 'wholesal', 'retail', 'ongata', 'rongai', 'kware', 'open', 'air', 'market', 'face', 'immin', 'closur', 'day', 'mid', 'combat', 'covid', '19', 'spread', 'move', 'leav', 'consum', 'merci', 'local', 'retail', 'enjoy', 'freedom', 'set', 'price', 'lookout', 'gikombacorona']

# %%
text["Tweet_token"] = text["Tweet"].apply(lambda x :  text_normalizer(x))

# %%
text
# Out:
#           Id                                              Tweet  Label  \
# 0          0  https://t.co/UpjxfOgQs8\r\r\n\r\r\nGaisss! Ple...      4
# 1          1  @mygovindia Today just after a week of lockdow...      1
# 2          2  Tuskys partners with Amref to provide on groun...      2
# 3          3  @chrissyteigen are u doing ur own grocery shop...      1
# 4          4  UK Critical Care Nurse Cries at Empty SuperMar...      0
# ...      ...                                                ...    ...
# 37036  37036  Minnesota classifies grocery store workers as ...      1
# 37037  37037  US Senator @ewarren has asked for information ...      1
# 37038  37038  Just commented on @thejournal_ie: Poll: Are yo...      0
# 37039  37039  My wife got laid off yesterday because the sma...      2
# 37040  37040  Humanity is doomed\r\r\n#coronavirus #coronacr...      0
#
#                                              Tweet_token
# 0      [gaisss, pleas, read, pleas, limit, go, outsid...
# 1      [today, week, lockdown, lot, confectionari, st...
# 2      [tuski, partner, amref, provid, ground, health...
# 3      [u, ur, groceri, shop, like, regular, person, ...
# 4      [uk, critic, care, nurs, cri, empti, supermark...
# ...                                                  ...
# 37036  [minnesota, classifi, groceri, store, worker, ...
# 37037  [us, senat, ask, inform, leveragedloan, price,...
# 37038  [comment, poll, onlin, shop, normal, covid, 19...
# 37039  [wife, got, laid, yesterday, small, retail, st...
# 37040  [human, doom, coronaviru, coronacrisi, toiletp...
#
# [37041 rows x 4 columns]

# %%
X = text["Tweet_token"]
y = text["Label"]

# %%
## train test split
## 8:2
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=200)

# %%
X_train
# Out:
# 10813    [probabl, first, time, ever, post, breitbart, ...
# 4169     [thing, keep, coronaviru, end, 1, polish, deli...
# 35718    [pop, store, give, mother, corona, viru, mothe...
# 19214    [updat, start, today', midnight, end, april, 2...
# 18482    [need, immedi, work, think, one, 1st, thing, i...
#                                ...
# 30939    [son, niec, lost, job, pizza, hut, drive, thru...
# 11343    [local, supermarket, pre-open, hour, exclus, n...
# 784      [usd, cad, climb, back, multi-year, top, aroun...
# 12905    [covid, 19, put, indian, economi, ventil, gove...
# 1818     [attent, californian, socal, supermarket, info...
# Name: Tweet_token, Length: 29632, dtype: object

# %% [markdown]
# # Create (word, label) dictionary

# %%
def frequency_dict(X_train, y_train):
    freq_dict = {}
    
    for text, y in zip(X_train, y_train):
        for word in text:
            ## pair : (bad, 0), (good, 4), ...
            pair = (word, y)
            
            freq_dict[pair] = freq_dict.get(pair, 0) + 1
    return freq_dict

# %%
# X_train_dummy = X_train[:1000]
# y_train_dummy = y_train[:1000]

# %%
freq = frequency_dict(X_train, y_train)
freq
# Out:
# {('probabl', 3): 33,
#  ('first', 3): 189,
#  ('time', 3): 641,
#  ('ever', 3): 70,
#  ('post', 3): 105,
#  ('breitbart', 3): 1,
#  ('articl', 3): 73,
#  ("i'm", 3): 121,
#  ('agreement', 3): 8,
#  ('spot', 3): 37,
#  ('insidertraitor', 3): 1,
#  ('fridaythought', 3): 5,
#  ('coronavirusupd', 3): 39,
#  ('covid', 3): 4452,
#  ('_19', 3): 580,
#  ('thing', 3): 222,
#  ('keep', 3): 378,
#  ('coronaviru', 3): 3246,
#  ('end', 3): 91,
#  ('1', 3): 201,
#  ('polish', 3): 3,
#  ('deli', 3): 4,
#  ('life', 3): 114,
#  ('meat', 3): 50,
#  ('delici', 3): 4,
#  ('coffe', 3): 17,
#  ('cheap', 3): 26,
#  ('tasti', 3): 2,
#  ('wast', 3): 23,
#  ('much', 3): 176,
#  ('shop', 3): 1087,
#  ('supermarket', 3): 1517,
#  ('pop', 2): 6,
#  ('store', 2): 1153,
#  ('give', 2): 53,
#  ('mother', 2): 15,
#  ('corona', 2): 126,
#  ('viru', 2): 115,
#  ('day', 2): 236,
#  ('lt', 2): 1,
#  ('3', 2): 86,
#  ('updat', 0): 40,
#  ('start', 0): 106,
#  ("today'", 0): 3,
#  ('midnight', 0): 7,
#  ('end', 0): 72,
#  ('april', 0): 21,
#  ('2020', 0): 57,
#  ('emerg', 0): 106,
#  ('decre', 0): 1,
#  ('enforc', 0): 16,
#  ('across', 0): 49,
#  ('thailand', 0): 6,
#  ('fight', 0): 108,
#  ('covid', 0): 2108,
#  ('19', 0): 1630,
#  ('pandem', 0): 259,
#  ('shop', 0): 423,
#  ('sell', 0): 80,
#  ('food', 0): 1153,
#  ('essenti', 0): 130,
#  ('consum', 0): 438,
#  ('good', 0): 94,
#  ('remain', 0): 25,
#  ('open', 0): 69,
#  ('wefightcovid', 0): 1,
#  ('flattenthecurv', 0): 5,
#  ('need', 1): 562,
#  ('immedi', 1): 20,
#  ('work', 1): 512,
#  ('think', 1): 202,
#  ('one', 1): 372,
#  ('1st', 1): 22,
#  ('thing', 1): 192,
#  ("i'd", 1): 10,
#  ('inquir', 1): 2,
#  ('drive', 1): 82,
#  ('amazon', 1): 84,
#  ('groceri', 1): 1142,
#  ('store', 1): 1387,
#  ('pharmaci', 1): 57,
#  ('typic', 1): 11,
#  ('deliveri', 1): 247,
#  ('servic', 1): 211,
#  ('critic', 1): 75,
#  ('deepli', 1): 7,
#  ('shelter', 1): 20,
#  ('coronaviru', 1): 3013,
#  ('covid', 1): 3744,
#  ('19', 1): 2838,
#  ('unemploy', 1): 55,
#  ('major', 1): 76,
#  ('supermarket', 1): 1391,
#  ('chain', 1): 178,
#  ('begin', 1): 65,
#  ('report', 1): 189,
#  ('relat', 1): 66,
#  ('employe', 1): 153,
#  ('death', 1): 68,
#  ('lead', 1): 61,
#  ('closur', 1): 56,
#  ('increas', 1): 235,
#  ('anxieti', 1): 46,
#  ('among', 1): 30,
#  ('worker', 1): 458,
#  ('pandem', 1): 583,
#  ('intensifi', 1): 12,
#  ('across', 1): 106,
#  ('countri', 1): 181,
#  ('today', 4): 206,
#  ('said', 4): 65,
#  ('hi', 4): 29,
#  ('ladi', 4): 22,
#  ('came', 4): 26,
#  ('back', 4): 111,
#  ('find', 4): 125,
#  ('5', 4): 67,
#  ('minut', 4): 23,
#  ('later', 4): 24,
#  ('ask', 4): 78,
#  ('pantyhos', 4): 1,
#  ('work', 4): 496,
#  ('groceri', 4): 838,
#  ('store', 4): 1083,
#  ('carri', 4): 19,
#  ('cross', 4): 10,
#  ('arm', 4): 7,
#  ('command', 4): 3,
#  ('look', 4): 175,
#  ('someon', 4): 50,
#  ('els', 4): 51,
#  ('help', 4): 892,
#  ('lol', 4): 25,
#  ('zzz', 4): 1,
#  ('covid', 4): 2533,
#  ('_19', 4): 329,
#  ('retail', 4): 243,
#  ('fuelupd', 2): 3,
#  ('petrol', 2): 13,
#  ('diesel', 2): 8,
#  ('price', 2): 940,
#  ('stagnant', 2): 3,
#  ('24th', 2): 2,
#  ('consecut', 2): 2,
#  ('amid', 2): 107,
#  ('covid', 2): 3035,
#  ('19', 2): 2250,
#  ('lockdown', 2): 200,
#  ('everyday', 1): 16,
#  ('ceo', 1): 45,
#  ('dougmcmillon', 1): 2,
#  ('tell', 1): 74,
#  ('lie', 1): 34,
#  ('compani', 1): 199,
#  ('protect', 1): 150,
#  ('associ', 1): 19,
#  ('hand', 1): 219,
#  ('sanit', 1): 271,
#  ('ppe', 1): 29,
#  ('hundr', 1): 21,
#  ('custom', 1): 184,
#  ('count', 1): 13,
#  ('limit', 1): 142,
#  ('option', 1): 30,
#  ('come', 1): 185,
#  ('get', 1): 650,
#  ('paid', 1): 43,
#  ('essentialwork', 1): 5,
#  ('frontlin', 1): 37,
#  ('larger', 1): 5,
#  ('adopt', 1): 4,
#  ('standard', 1): 12,
#  ('open', 1): 149,
#  ('hour', 1): 150,
#  ('sunday', 1): 24,
#  ('rather', 1): 32,
#  ('close', 1): 191,
#  ('4pm', 1): 2,
#  ('wider', 1): 1,
#  ('window', 1): 10,
#  ('lower', 1): 115,
#  ('volum', 1): 7,
#  ('shopper', 1): 82,
#  ('lessen', 1): 3,
#  ('risk', 1): 206,
#  ('cross-contamin', 1): 1,
#  ('call', 4): 121,
#  ('healthcar', 4): 81,
#  ('system', 4): 56,
#  ('worker', 4): 549,
#  ('essenti', 4): 183,
#  ('industri', 4): 79,
#  ('collect', 4): 21,
#  ('global', 4): 52,
#  ('win', 4): 37,
#  ('year', 4): 77,
#  ('probabl', 4): 21,
#  ('possibl', 4): 41,
#  ('whatev', 4): 11,
#  ('good', 4): 373,
#  ('night', 4): 26,
#  ('19', 4): 2045,
#  ('coronaviru', 4): 1849,
#  ('stayhom', 4): 64,
#  ('overbuy', 3): 3,
#  ('food', 3): 1317,
#  ('unit', 3): 56,
#  ('airlin', 3): 30,
#  ('stock', 3): 573,
#  ('marketcrash', 3): 5,
#  ('healthcar', 2): 30,
#  ('profession', 2): 13,
#  ('better', 2): 6,
#  ('get', 2): 352,
#  ('coronaviru', 2): 2555,
#  ('supermarket', 2): 1040,
#  ('somebodi', 2): 5,
#  ('mild', 2): 1,
#  ('simptom', 2): 1,
#  ('entub', 2): 1,
#  ('critic', 2): 3,
#  ('ill', 2): 5,
#  ('patient', 2): 14,
#  ('self-quarantin', 3): 6,
#  ('mysteri', 3): 3,
#  ('can', 3): 14,
#  ('littl', 3): 72,
#  ('humor', 3): 28,
#  ('help', 3): 644,
#  ('us', 3): 488,
#  ('get', 3): 763,
#  ('difficult', 3): 29,
#  ('stay', 3): 373,
#  ('safe', 3): 221,
#  ('funni', 3): 32,
#  ('laugh', 3): 29,
#  ('smile', 3): 6,
#  ('comic', 3): 10,
#  ('comedi', 3): 13,
#  ('joke', 3): 30,
#  ('satir', 3): 2,
#  ('groceri', 3): 1502,
#  ('store', 3): 1752,
#  ('quarantin', 3): 170,
#  ('viru', 3): 206,
#  ('19', 3): 3458,
#  ('pandem', 3): 663,
#  ('spirit', 3): 16,
#  ('caution', 3): 3,
#  ('share', 3): 163,
#  ('spoke', 3): 14,
#  ('friend', 3): 90,
#  ('got', 3): 150,
#  ('call', 3): 176,
#  ('emerg', 3): 105,
#  ('meet', 3): 120,
#  ('hospit', 3): 93,
#  ('said', 3): 152,
#  ('spread', 3): 247,
#  ('quickli', 3): 29,
#  ('ga', 3): 125,
#  ('pump', 3): 21,
#  ('cart', 3): 36,
#  ('wear', 3): 139,
#  ('glove', 3): 127,
#  ('take', 3): 404,
#  ('appropri', 3): 11,
#  ('measur', 3): 118,
#  ('washyourhand', 3): 21,
#  ('dylan', 2): 1,
#  ('morrison', 2): 17,
#  ('ny', 2): 8,
#  ('time', 2): 269,
#  ('advic', 2): 42,
#  ('groceri', 2): 919,
#  ('worker', 2): 171,
#  ('lockdown', 3): 254,
#  ('need', 3): 778,
#  ('war', 3): 15,
#  ('agric', 3): 3,
#  ('minist', 3): 20,
#  ('citinewsroom', 3): 1,
#  ('find', 3): 206,
#  ('staff', 3): 242,
#  ('protect', 3): 270,
#  ('dream', 1): 9,
#  ('go', 1): 732,
#  ('find', 1): 157,
#  ('pasta', 1): 34,
#  ('2019', 1): 305,
#  ('museveni', 1): 5,
#  ('want', 1): 172,
#  ('ugandan', 1): 6,
#  ('use', 1): 264,
#  ('bicycl', 1): 2,
#  ('warn', 1): 100,
#  ('trader', 1): 37,
#  ('hike', 1): 74,
#  ('food', 1): 1483,
#  ('price', 1): 1930,
#  ('4th', 1): 5,
#  ('address', 1): 22,
#  ('nation', 1): 99,
#  ('tcoronaviru', 1): 1,
#  ('epidem', 1): 21,
#  ('tuesday', 1): 10,
#  ('said', 1): 148,
#  ('serious', 1): 57,
#  ('consid', 1): 53,
#  ('suspend', 1): 27,
#  ('public', 1): 128,
#  ('transport', 1): 27,
#  ('buy', 1): 642,
#  ('shirt', 1): 5,
#  ('alonetogeth', 1): 3,
#  ('quarantin', 1): 143,
#  ('toiletpaperpan', 1): 27,
#  ('toiletpap', 1): 212,
#  ('funni', 1): 14,
#  ('viru', 1): 185,
#  ('washyourhand', 1): 8,
#  ('stayhometexa', 1): 1,
#  ('meme', 1): 8,
#  ('chinaliedandpeopledi', 1): 2,
#  ('coronavirusupd', 1): 77,
#  ('toiletpapercrisi', 1): 30,
#  ('stayhom', 1): 61,
#  ('china', 1): 86,
#  ('consum', 3): 1071,
#  ('expert', 3): 59,
#  ('ami', 3): 2,
#  ('davi', 3): 2,
#  ('tell', 3): 102,
#  ('make', 3): 457,
#  ('sure', 3): 138,
#  ('pay', 3): 139,
#  ('servic', 3): 243,
#  ('use', 3): 378,
#  ('great', 3): 91,
#  ('advic', 3): 43,
#  ('manag', 3): 97,
#  ('mental', 3): 12,
#  ('health', 3): 229,
#  ('period', 3): 46,
#  ('bbc', 3): 10,
#  ('talk', 3): 59,
#  ('anxiou', 3): 9,
#  ('child', 3): 20,
#  ('teen', 3): 4,
#  ('anxieti', 3): 17,
#  ('uk', 3): 115,
#  ('toiletpap', 4): 133,
#  ('facilit', 4): 3,
#  ('free', 4): 305,
#  ('tp', 4): 32,
#  ('direct', 4): 30,
#  ('consum', 4): 589,
#  ('custom', 4): 213,
#  ('mean', 4): 62,
#  ('human', 4): 42,
#  ('peopl', 4): 593,
#  ('buy', 4): 228,
#  ('product', 4): 196,
#  ('like', 4): 580,
#  ('crazi', 4): 19,
#  ('fear', 4): 9,
#  ('bigbiz', 4): 1,
#  ('corpor', 4): 22,
#  ('spare', 4): 11,
#  ('lotta', 4): 1,
#  ('squar', 4): 3,
#  ('happen', 4): 50,
#  ('plucki', 4): 1,
#  ('brit', 4): 2,
#  ('flag', 4): 2,
#  ('wave', 4): 9,
#  ('dunkirk', 4): 1,
#  ('great', 4): 310,
#  ('britain', 4): 8,
#  ('spirit', 4): 20,
#  ('everyon', 4): 213,
#  ('bang', 4): 2,
#  ('recent', 4): 37,
#  ('strip', 4): 9,
#  ('supermarket', 4): 860,
#  ('shelv', 4): 114,
#  ('plagu', 4): 3,
#  ('cocain', 4): 1,
#  ('fuell', 4): 1,
#  ('locust', 4): 2,
#  ('attitud', 4): 4,
#  ('instead', 4): 36,
#  ('2019', 4): 193,
#  ('...', 4): 387,
#  ('go', 4): 490,
#  ('get', 4): 463,
#  ('food', 4): 758,
#  ('local', 4): 275,
#  ('noth', 4): 36,
#  ('left', 4): 32,
#  ('finish', 4): 6,
#  ('shift', 4): 37,
#  ('nh', 4): 80,
#  ('two', 4): 76,
#  ('lot', 4): 80,
#  ('offic', 4): 44,
#  ('patrol', 4): 2,
#  ('make', 4): 385,
#  ('sure', 4): 119,
#  ('staff', 4): 243,
#  ('abus', 4): 4,
#  ('pleas', 4): 487,
#  ('kind', 4): 83,
#  ('bekind', 4): 8,
#  ('everi', 3): 187,
#  ('look', 3): 311,
#  ('anyon', 3): 107,
#  ('know', 3): 283,
#  ('someon', 3): 95,
#  ('work', 3): 614,
#  ('hour', 3): 191,
#  ('cut', 3): 86,
#  ('busi', 3): 377,
#  ('due', 3): 333,
#  ('appli', 3): 28,
#  ('onlin', 3): 798,
#  ('contact', 3): 83,
#  ('local', 3): 331,
#  ('becom', 3): 58,
#  ('like', 3): 726,
#  ('fantasi', 3): 1,
#  ('footbal', 3): 10,
#  ('wife', 3): 24,
#  ('tinker', 3): 1,
#  ('line-up', 3): 1,
#  ('day', 3): 414,
#  ('hamont', 3): 2,
#  ('coronacrisi', 3): 123,
#  ('alert', 3): 55,
#  ('close', 3): 297,
#  ('canada', 3): 45,
#  ('amid', 3): 173,
#  ('today', 0): 133,
#  ('went', 0): 79,
#  ('store', 0): 599,
#  ('everyth', 0): 55,
#  ('sold', 0): 26,
#  ('price', 0): 1153,
#  ('rais', 0): 51,
#  ('fuck', 0): 149,
#  ('bad', 0): 100,
#  ('buckwheat', 0): 1,
#  ('return', 0): 26,
#  ('pharmaci', 0): 34,
#  ('noth', 0): 55,
#  ('denmark', 1): 8,
#  ('got', 1): 138,
#  ('tire', 1): 15,
#  ('peopl', 1): 1042,
#  ('hoard', 1): 156,
#  ('came', 1): 30,
#  ('way', 1): 164,
#  ('stop', 1): 315,
#  ('1', 1): 189,
#  ('bottl', 1): 38,
#  ('kr40', 1): 3,
#  ('5', 1): 70,
#  ('50', 1): 58,
#  ('2', 1): 241,
#  ('kr1000', 1): 3,
#  ('134', 1): 2,
#  ('00', 1): 5,
#  ('poultri', 1): 10,
#  ('farmer', 1): 69,
#  ('karnataka', 1): 3,
#  ('feel', 1): 79,
#  ('effect', 1): 86,
#  ('wholesal', 1): 18,
#  ('crash', 1): 37,
#  ('kroger', 3): 14,
#  ('subsidiari', 3): 3,
#  ('incl', 3): 4,
#  ('fred', 3): 4,
#  ('meyer', 3): 4,
#  ("ralph'", 3): 2,
#  ("fry'", 3): 1,
#  ('king', 3): 8,
#  ('sooper', 3): 3,
#  ('other', 3): 122,
#  ('largest', 3): 18,
#  ('chain', 3): 166,
#  ('employe', 3): 269,
#  ('must', 3): 104,
#  ('symptom', 3): 29,
#  ('pleas', 3): 407,
#  ('re-post', 3): 1,
#  ('mintel', 3): 2,
#  ('chang', 3): 249,
#  ('way', 3): 221,
#  ('eat', 3): 66,
#  ('travel', 3): 79,
#  ('congreg', 3): 3,
#  ('relat', 3): 59,
#  ('world', 3): 168,
#  ('around', 3): 135,
#  ("we'r", 3): 72,
#  ('also', 3): 216,
#  ('uncov', 3): 2,
#  ('opportun', 3): 49,
#  ('shift', 3): 97,
#  ("consumer'", 3): 3,
#  ('learn', 3): 119,
#  ('spain', 0): 9,
#  ('costa', 0): 2,
#  ('del', 0): 3,
#  ('sol', 0): 1,
#  ('supermarket', 0): 757,
#  ('take', 0): 180,
#  ('action', 0): 38,
#  ('fake', 0): 51,
#  ('news', 0): 81,
#  ('spreader', 0): 2,
#  ('lie', 0): 36,
#  ('staff', 0): 80,
#  ('infect', 0): 75,
#  ('euro', 0): 6,
#  ('weekli', 0): 18,
#  ('articl', 0): 10,
#  ('crude', 0): 83,
#  ('oil', 0): 340,
#  ('collaps', 0): 77,
#  ('demand', 0): 279,
#  ('low', 0): 157,
#  ('callou', 0): 2,
#  ('govern', 0): 116,
#  ('tax', 0): 16,
#  ('indian', 0): 12,
#  ('impos', 0): 9,
#  ('excis', 0): 1,
#  ('duti', 0): 6,
#  ('petrol', 0): 15,
#  ('diesel', 0): 4,
#  ('make', 0): 211,
#  ('merri', 0): 1,
#  ('depress', 0): 30,
#  ('environ', 0): 9,
#  ('rude', 0): 11,
#  ('hope', 4): 185,
#  ('never', 4): 62,
#  ('hear', 4): 34,
#  ('anyon', 4): 67,
#  ('trash', 4): 7,
#  ('certain', 4): 29,
#  ('type', 4): 15,
#  ('job', 4): 114,
#  ('fast', 4): 21,
#  ('walmart', 4): 26,
#  ('employe', 4): 185,
#  ('secur', 4): 65,
#  ('even', 4): 129,
#  ('think', 4): 151,
#  ('deserv', 4): 35,
#  ('wage', 4): 24,
#  ('surviv', 4): 48,
#  ('damn', 3): 17,
#  ('straight', 3): 17,
#  ('janitor', 3): 8,
#  ('personnel', 3): 23,
#  ('truck', 3): 50,
#  ('driver', 3): 129,
#  ('clean', 3): 98,
#  ('crew', 3): 5,
#  ('medic', 3): 133,
#  ('profession', 3): 25,
#  ('true', 3): 35,
#  ('thank', 3): 338,
#  ('job', 3): 129,
#  ('seen', 1): 90,
#  ('man', 1): 76,
#  ('oh', 1): 25,
#  ('hey', 1): 24,
#  ('extend', 1): 21,
#  ('shake', 1): 11,
#  ('sarcast', 1): 1,
#  ('):', 1): 8,
#  ('laugh', 1): 9,
#  ('wife', 1): 24,
#  ('know', 1): 238,
#  ('whole', 1): 40,
#  ('stupid', 1): 33,
#  ('guy', 1): 47,
#  ('sick', 1): 64,
#  ('die', 1): 127,
#  ('coronacrisi', 1): 145,
#  ('knew', 1): 16,
#  ('matter', 1): 32,
#  ('time', 1): 567,
#  ('first', 1): 119,
#  ('racist', 1): 4,
#  ('remark', 1): 2,
#  ('era', 1): 5,
#  ('aim', 1): 8,
#  ('area', 1): 67,
#  ('nearbi', 1): 4,
#  ('target', 1): 26,
#  ('white', 1): 22,
#  ('woman', 1): 50,
#  ('jump', 1): 19,
#  ('jesu', 1): 3,
#  ('christ', 1): 2,
#  ('give', 1): 88,
#  ('even', 1): 207,
#  ('american', 1): 96,
#  ('someth', 1): 63,
#  ('free', 1): 33,
#  ('attract', 1): 1,
#  ('mani', 1): 241,
#  ('car', 1): 63,
#  ('notic', 1): 38,
#  ('hoopti', 1): 1,
#  ('anoth', 1): 94,
#  ('feed', 1): 32,
#  ('panic', 1): 579,
#  ('stori', 1): 63,
#  ('chinaflu', 1): 1,
#  ('peopl', 0): 912,
#  ('sick', 0): 103,
#  ('ask', 0): 60,
#  ('dna', 0): 2,
#  ('genom', 0): 2,
#  ('compani', 0): 91,
#  ('23andm', 0): 1,
#  ('want', 0): 91,
#  ('mine', 0): 11,
#  ('databas', 0): 4,
#  ('million', 0): 63,
#  ('custom', 0): 91,
#  ('clue', 0): 7,
#  ('viru', 0): 164,
#  ('hit', 0): 73,
#  ('harder', 0): 4,
#  ('other', 0): 65,
#  ('check', 4): 95,
#  ('video', 4): 46,
#  ('handl', 4): 34,
#  ('item', 4): 121,
#  ('take-out', 4): 3,
#  ('valu', 3): 47,
#  ('inflat', 3): 64,
#  ('buyback', 3): 4,
#  ('own', 3): 11,
#  ('abilti', 3): 1,
#  ('forc', 3): 59,
#  ('price', 3): 1643,
#  ('surg', 3): 68,
#  ('author', 3): 39,
#  ('tax', 3): 40,
#  ('scam', 3): 26,
#  ('gopinsidertrad', 3): 1,
#  ('trumpli', 3): 1,
#  ('despit', 3): 52,
#  ('govern', 3): 203,
#  ('impos', 3): 12,
#  ('cap', 3): 15,
#  ('mask', 3): 392,
#  ('sanitis', 3): 48,
#  ('either', 3): 23,
#  ('market', 3): 350,
#  ('sold', 3): 49,
#  ('mrp', 3): 3,
#  ('coronalockdown', 3): 5,
#  ('2019', 3): 342,
#  ('news', 3): 156,
#  ('thought', 2): 34,
#  ('one', 2): 189,
#  ('stock', 2): 255,
#  ('pile', 2): 9,
#  ('toilet', 2): 241,
#  ('roll', 2): 87,
#  ('could', 2): 97,
#  ('hygien', 2): 10,
#  ('cough', 2): 70,
#  ('tissu', 2): 15,
#  ('hand', 2): 101,
#  ('food', 2): 489,
#  ('buy', 2): 192,
#  ('nan', 2): 4,
#  ('young', 2): 7,
#  ('children', 2): 12,
#  ('fda', 2): 9,
#  ('offici', 2): 27,
#  ('mitch', 2): 1,
#  ('zeller', 2): 1,
#  ('discuss', 2): 42,
#  ('need', 2): 322,
#  ('quickli', 2): 14,
#  ('approv', 2): 3,
#  ('treatment', 2): 9,
#  ('test', 2): 95,
#  ('uphold', 2): 1,
#  ('scientif', 2): 3,
#  ('standard', 2): 12,
#  ('pandem', 2): 387,
#  ('bedrock', 2): 1,
#  ('principl', 2): 1,
#  ('consum', 2): 819,
#  ('protect', 2): 101,
#  ('remain', 2): 46,
#  ('unchang', 2): 4,
#  ('write', 2): 13,
#  ('new', 2): 259,
#  ('emerg', 2): 40,
#  ('fund', 2): 21,
#  ('provid', 2): 65,
#  ('voucher', 2): 8,
#  ('help', 2): 80,
#  ('bill', 2): 16,
#  ('york', 2): 18,
#  ('resid', 2): 23,
#  ('due', 2): 199,
#  ('onlin', 2): 496,
#  ('shop', 2): 713,
#  ('fall', 2): 56,
#  ('16', 2): 15,
#  ('info', 2): 24,
#  ('visit', 2): 50,
#  ('latestnew', 2): 1,
#  ('uniquetim', 2): 1,
#  ('coronaviruslatestupd', 2): 1,
#  ('19new', 2): 3,
#  ('onlineshop', 2): 15,
#  ('take', 1): 346,
#  ('precaut', 1): 22,
#  ('avoid', 1): 125,
#  ('step', 1): 53,
#  ('help', 1): 231,
#  ('prevent', 1): 59,
#  ('devic', 1): 7,
#  ('catch', 1): 44,
#  ('virus', 1): 10,
#  ('click', 1): 20,
#  ('resourc', 1): 36,
#  ('scam', 1): 132,
#  ('keep', 1): 256,
#  ('secur', 1): 46,
#  ('remot', 1): 10,
#  ('receiv', 3): 65,
#  ('deliveri', 3): 338,
#  ('packag', 3): 58,
#  ('even', 3): 201,
#  ('non', 3): 34,
#  ('essenti', 3): 302,
#  ('item', 3): 222,
#  ('amazon', 3): 108,
#  ('let', 3): 140,
#  ('peopl', 3): 1025,
#  ('buy', 3): 480,
#  ('hand', 3): 726,
#  ('sanit', 3): 744,
#  ('face', 3): 211,
#  ('fuck', 3): 28,
#  ('els', 3): 76,
#  ('good', 3): 347,
#  ('limit', 3): 126,
#  ('u', 3): 133,
#  ('max', 3): 1,
#  ('2', 3): 278,
#  ('mayb', 3): 42,
#  ('idk', 3): 4,
#  ('stuff', 3): 57,
#  ('everyon', 3): 225,
#  ('ok', 1): 25,
#  ('shit', 1): 63,
#  ('crazi', 1): 69,
#  ('buddi', 1): 1,
#  ('direct', 1): 43,
#  ('contact', 1): 55,
#  ('person', 1): 108,
#  ('test', 1): 118,
#  ('posit', 1): 33,
#  ('produc', 1): 92,
#  ('forc', 1): 97,
#  ('still', 1): 239,
#  ('let', 1): 99,
#  ('..', 1): 137,
#  ('lay', 1): 6,
#  ('demand', 1): 678,
#  ('next', 2): 75,
#  ('phase', 2): 8,
#  ('first', 2): 99,
#  ('went', 2): 71,
#  ('disinfect', 2): 29,
#  ('hair', 2): 9,
#  ('clipper', 2): 3,
#  ('dye', 2): 2,
#  ('fli', 2): 8,
#  ('shelv', 2): 78,
#  ('spain', 4): 8,
#  ('union', 4): 11,
#  ('better', 4): 140,
#  ('protect', 4): 228,
#  ('take', 4): 255,
#  ('toll-uni', 4): 1,
#  ('thrive', 1): 4,
#  ('commun', 1): 95,
#  ('sell', 1): 139,
#  ('toilet', 1): 259,
#  ('paper', 1): 253,
#  ('outrag', 1): 12,
#  ('onlin', 1): 491,
#  ('actual', 1): 55,
#  ('mondaythought', 1): 4,
#  ('think', 3): 221,
#  ('may', 3): 162,
#  ('experi', 3): 51,
#  ('financi', 3): 84,
#  ('hardship', 3): 14,
#  ('current', 3): 130,
#  ('soon', 3): 59,
#  ('possibl', 3): 99,
#  ('read', 3): 182,
#  ('tip', 3): 112,
#  ('photo', 3): 32,
#  ('scene', 3): 15,
#  ('1993', 3): 2,
#  ('john', 3): 8,
#  ('goodman', 3): 1,
#  ('hit', 3): 74,
#  ('matine', 3): 1,
#  ('set', 3): 64,
#  ('cuban', 3): 3,
#  ('missil', 3): 1,
#  ('crisi', 3): 150,
#  ('never', 3): 106,
#  ('seen', 3): 88,
#  ('check', 3): 188,
#  ('fun', 3): 21,
#  ('6.6', 1): 2,
#  ('oz', 1): 5,
#  ('80', 1): 21,
#  ('alcohol', 1): 32,
#  ('high', 1): 152,
#  ('content', 1): 12,
#  ('kill', 1): 58,
#  ('neutral', 1): 2,
#  ('compar', 1): 25,
#  ('thicker', 1): 1,
#  ('gel-typ', 1): 1,
#  ('sold', 1): 51,
#  ('grab', 1): 23,
#  ('busi', 1): 279,
#  ('sales@culturestudio.net', 1): 1,
#  ('handsanit', 1): 19,
#  ('promoitem', 1): 1,
#  ('chicagomad', 1): 1,
#  ('rais', 2): 40,
#  ('sage', 3): 1,
#  ('report', 3): 200,
#  ('prepar', 3): 88,
#  ('say', 3): 290,
#  ('larg', 3): 38,
#  ('scale', 3): 6,
#  ('riot', 3): 3,
#  ('unlik', 3): 13,
#  ('rare', 3): 7,
#  ('circumst', 3): 9,
#  ('80', 3): 22,
#  ('tori', 3): 4,
#  ('polici', 3): 37,
#  ('whoever', 3): 9,
#  ('wrote', 3): 7,
#  ('clearli', 3): 24,
#  ('toilet', 3): 301,
#  ('roll', 3): 107,
#  ('aisl', 3): 56,
#  ('trump', 1): 97,
#  ('cannot', 1): 56,
#  ('stand', 1): 43,
#  ('ga', 1): 174,
#  ('1990', 1): 1,
#  ('cheaper', 1): 7,
#  ('without', 1): 87,
#  ('like', 1): 351,
#  ('bill', 1): 53,
#  ('clinton', 1): 1,
#  ('presid', 1): 43,
#  ('amp', 1): 213,
#  ('balanc', 1): 4,
#  ('budget', 1): 24,
#  ('carer', 2): 5,
#  ('sainsburi', 2): 14,
#  ('veget', 2): 32,
#  ('anyth', 2): 20,
#  ('els', 2): 26,
#  ('told', 2): 28,
#  ('tri', 2): 83,
#  ('local', 2): 169,
#  ('slot', 2): 16,
#  ('anywher', 2): 8,
#  ('hope', 2): 11,
#  ('stop', 2): 24,
#  ('soon', 2): 30,
#  ('mean', 2): 65,
#  ('go', 2): 444,
#  ('around', 2): 81,
#  ('quit', 2): 8,
#  ('airlin', 1): 19,
#  ('fare', 1): 8,
#  ('_19', 1): 522,
#  ('outbreak', 1): 233,
#  ('famili', 1): 138,
#  ('apart', 1): 27,
#  ('shame', 1): 51,
#  ('wisconsin', 1): 7,
#  ('dairi', 1): 23,
#  ('dump', 1): 19,
#  ('milk', 1): 69,
#  ('fall', 1): 148,
#  ("i'm", 0): 86,
#  ('sure', 0): 35,
#  ('weather', 0): 10,
#  ('feel', 0): 68,
#  ('real', 0): 52,
#  ('american', 0): 73,
#  ('presid', 0): 28,
#  ('help', 0): 96,
#  ('care', 0): 38,
#  ('left', 0): 61,
#  ('right', 0): 106,
#  ('lean', 0): 3,
#  ('chipchirp', 2): 1,
#  ("vlsiresearch'", 2): 1,
#  ('app', 2): 27,
#  ("vlsi'", 2): 1,
#  ('semiconductor', 2): 1,
#  ('market', 2): 238,
#  ('watch', 2): 66,
#  ('week', 2): 179,
#  ('6', 2): 49,
#  ('last', 2): 84,
#  ('ic', 2): 2,
#  ('sale', 2): 83,
#  ('rebound', 2): 3,
#  ('4', 2): 58,
#  ('unit', 2): 9,
#  ('5', 2): 73,
#  ('year', 2): 89,
#  ('tma', 2): 1,
#  ('slid', 2): 1,
#  ('1', 2): 95,
#  ('brought', 2): 13,
#  ('comp', 2): 2,
#  ('back', 2): 100,
#  ('averag', 2): 18,
#  ('7', 2): 31,
#  ('_19', 2): 444,
#  ('usa', 2): 21,
#  ('europ', 2): 21,
#  ('lead', 2): 24,
#  ('firm', 2): 20,
#  ('intl', 2): 2,
#  ('pull', 2): 15,
#  ('togeth', 2): 48,
#  ('regular', 2): 10,
#  ('tracker', 2): 10,
#  ('impact', 2): 238,
#  ('spend', 2): 82,
#  ('implic', 2): 6,
#  ('brand', 2): 48,
#  ('found', 3): 64,
#  ('paper', 3): 308,
#  ('towel', 3): 21,
#  ('week', 3): 357,
#  ('treat', 3): 39,
#  ('rever', 3): 1,
#  ('amd', 3): 1,
#  ('respect', 3): 41,
#  ('deserv', 3): 29,
#  ('everybodi', 0): 10,
#  ('panic', 0): 826,
#  ('begun', 0): 3,
#  ('monkey', 0): 2,
#  ('soon', 0): 34,
#  ('surviv', 0): 44,
#  ('live', 0): 102,
#  ('planet', 0): 9,
#  ('run', 0): 70,
#  ('ape', 0): 1,
#  ('need', 0): 413,
#  ('mass', 0): 23,
#  ('riot', 0): 17,
#  ('everyon', 0): 98,
#  ('street', 0): 29,
#  ('social', 0): 114,
#  ('distanc', 0): 68,
#  ('answer', 0): 14,
#  ('planetoftheap', 0): 1,
#  ('coronaviru', 0): 1662,
#  ('ye', 3): 58,
#  ('strategi', 3): 26,
#  ...}

# %% [markdown]
# # Train Naive Bayes

# %%
N_label_tweet = y_train.value_counts().to_dict()
N_label_tweet
# Out:
# {3: 8182, 1: 7123, 2: 5548, 4: 4817, 0: 3962}

# %%
def Naive_Bayes_Train(freq, X_train, y_train, N_label_tweet):
    '''
    Input : word frequency, train data, number of tweets for each class
    Output : logprior, loglikelihood
    '''
    
    loglikelihood = {}
    logprior = 0
    
    ## # of unique words
    unique_words = set([pair[0] for pair in freq.keys()])
    V = len(unique_words)
    
    ## the number of pairs for each label
    N_label = {}
    for pair in freq.keys():
        for i in [0,1,2,3,4]:
            if pair[1] == i:
                N_label[i] = N_label.get(i, 0) + freq[pair]
#     print(N_label)
                
    ## tot num of tweet
    N_tweet = len(y_train)
#     print(N_tweet)
#     print(np.log(N_label_tweet[0]) - np.log(N_tweet - N_label_tweet[0]))
    
    ## logprior
    logprior = [np.log(N_label_tweet[0]) - np.log(N_tweet - N_label_tweet[0]),
               np.log(N_label_tweet[1]) - np.log(N_tweet - N_label_tweet[1]),
               np.log(N_label_tweet[2]) - np.log(N_tweet - N_label_tweet[2]),
               np.log(N_label_tweet[3]) - np.log(N_tweet - N_label_tweet[3]),
               np.log(N_label_tweet[4]) - np.log(N_tweet - N_label_tweet[4])]
    
    
    for word in unique_words:
        
        ## frequency of the word
        freq_0 = freq.get((word, 0), 0)
        freq_1 = freq.get((word, 1), 0)
        freq_2 = freq.get((word, 2), 0)
        freq_3 = freq.get((word, 3), 0)
        freq_4 = freq.get((word, 4), 0)
        
#         print(freq_0)
#         print(freq_1)
#         print(freq_2)
#         print(freq_3)
#         print(freq_4)
        
        
        ## probability of the word is in each class
        p_w_0 = (freq_0 + 1) / (N_label[0] + V)
        p_w_1 = (freq_1 + 1) / (N_label[1] + V)
        p_w_2 = (freq_2 + 1) / (N_label[2] + V)
        p_w_3 = (freq_3 + 1) / (N_label[3] + V)
        p_w_4 = (freq_4 + 1) / (N_label[4] + V)
        
        p_w_not_0 = (freq_1+freq_2+freq_3+freq_4+1) / (N_label[1]+N_label[2]+N_label[3]+N_label[4]+V)
        p_w_not_1 = (freq_0+freq_2+freq_3+freq_4+1) / (N_label[0]+N_label[2]+N_label[3]+N_label[4]+V)
        p_w_not_2 = (freq_0+freq_1+freq_3+freq_4+1) / (N_label[0]+N_label[1]+N_label[3]+N_label[4]+V)
        p_w_not_3 = (freq_0+freq_1+freq_2+freq_4+1) / (N_label[0]+N_label[1]+N_label[2]+N_label[4]+V)
        p_w_not_4 = (freq_0+freq_1+freq_2+freq_3+1) / (N_label[0]+N_label[1]+N_label[2]+N_label[3]+V)
        
        
#         print(p_w_0)
#         print(p_w_1)
#         print(p_w_2)
#         print(p_w_3)
#         print(p_w_4)
 
        
        ## log likelihood of the word
        loglikelihood[word] = [np.log(p_w_0 / p_w_not_0),
                               np.log(p_w_1 / p_w_not_1),
                               np.log(p_w_2 / p_w_not_2),
                              np.log(p_w_3 / p_w_not_3),
                              np.log(p_w_4 / p_w_not_4)]
        
    return logprior, loglikelihood

                               
## https://www.youtube.com/watch?v=OsSkjrNjqNI

# %%
logprior, loglikelihood = Naive_Bayes_Train(freq, X_train, y_train, N_label_tweet)

# %% [markdown]
# # Prediction

# %%
def prediction(tweet, logprior, loglikelihood):
    p = {}
    for i in [0,1,2,3,4]:
        p[i] = logprior[i]
    
    for word in tweet:
        if word in loglikelihood:
            for i in [0,1,2,3,4]:
                p[i] += loglikelihood[word][i]
    
    return max(p, key=p.get)

# %%
y_pred = X_test.map(lambda x : prediction(x, logprior, loglikelihood))

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.4629504656498853

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[ 419,  414,   29,  107,   15],
#        [ 225,  846,  100,  562,   74],
#        [  30,  327,  454,  518,   53],
#        [  65,  413,  123, 1170,  329],
#        [   5,   79,   18,  493,  541]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      0.43      0.48       984
#            1       0.41      0.47      0.44      1807
#            2       0.63      0.33      0.43      1382
#            3       0.41      0.56      0.47      2100
#            4       0.53      0.48      0.50      1136
#
#     accuracy                           0.46      7409
#    macro avg       0.51      0.45      0.47      7409
# weighted avg       0.49      0.46      0.46      7409

# %%
fig = sns.heatmap(cm, cmap = 'Blues', annot=True)
fig.set(xlabel='y_pred', ylabel='y_ture')
# Out:
# [Text(33.0, 0.5, 'y_ture'), Text(0.5, 15.0, 'y_pred')]

# %% [markdown]
# ## Cross Validation

# %%
kf = KFold(n_splits=10, shuffle = True)
kf.get_n_splits(X)


accuracy = []
f1score = []
precision = []
recall = []

for train_index, test_index in kf.split(X):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    freq = frequency_dict(X_train, y_train)
    N_label_tweet = y_train.value_counts().to_dict()
    logprior, loglikelihood = Naive_Bayes_Train(freq, X_train, y_train, N_label_tweet)
    y_pred = X_test.map(lambda x : prediction(x, logprior, loglikelihood))
    accuracy.append(accuracy_score(y_test, y_pred))
    f1score.append(f1_score(y_test, y_pred, average='macro'))
    precision.append(precision_score(y_test, y_pred, average='macro'))
    recall.append(recall_score(y_test, y_pred, average='macro'))
# Out:
# TRAIN: [    0     1     2 ... 37038 37039 37040] TEST: [    3     8    29 ... 36990 37009 37016]
# TRAIN: [    0     1     2 ... 37037 37038 37039] TEST: [   14    21    31 ... 37019 37021 37040]
# TRAIN: [    0     1     2 ... 37037 37038 37040] TEST: [   10    11    22 ... 37032 37033 37039]
# TRAIN: [    1     2     3 ... 37038 37039 37040] TEST: [    0    15    17 ... 37027 37028 37035]
# TRAIN: [    0     1     2 ... 37038 37039 37040] TEST: [    4     5     6 ... 37008 37020 37037]
# TRAIN: [    0     1     2 ... 37038 37039 37040] TEST: [   25    38    48 ... 37017 37018 37023]
# TRAIN: [    0     1     2 ... 37038 37039 37040] TEST: [   30    56    61 ... 36998 37010 37030]
# TRAIN: [    0     2     3 ... 37038 37039 37040] TEST: [    1    12    46 ... 37022 37026 37036]
# TRAIN: [    0     1     3 ... 37037 37039 37040] TEST: [    2    16    18 ... 37029 37034 37038]
# TRAIN: [    0     1     2 ... 37038 37039 37040] TEST: [   13    23    28 ... 37003 37015 37024]

# %%
## average score of 10-fold cross validation
print("Accuracy : ",sum(accuracy)/10)
print("Precision : ",sum(precision)/10)
print("Recall : ",sum(recall)/10)
print("F1 score : ",sum(f1score)/10)
# Out:
# Accuracy :  0.47428504181203957
# Precision :  0.5245030612317376
# Recall :  0.4621541239653066
# F1 score :  0.4783557359786368

# %% [markdown]
# # word2vec approach

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
import numpy as np
import pandas as pd

import tensorflow_hub as hub
import numpy as np

# %% [markdown]
# ### Load pretrained model

# %%
import tensorflow_hub as hub
# embed = hub.load("https://tfhub.dev/google/Wiki-words-250/2")
embed = hub.load("https://tfhub.dev/google/tf2-preview/nnlm-en-dim128/1")

# %%
text
# Out:
#           Id                                              Tweet  Label  \
# 0          0  https://t.co/UpjxfOgQs8\r\r\n\r\r\nGaisss! Ple...      4
# 1          1  @mygovindia Today just after a week of lockdow...      1
# 2          2  Tuskys partners with Amref to provide on groun...      2
# 3          3  @chrissyteigen are u doing ur own grocery shop...      1
# 4          4  UK Critical Care Nurse Cries at Empty SuperMar...      0
# ...      ...                                                ...    ...
# 37036  37036  Minnesota classifies grocery store workers as ...      1
# 37037  37037  US Senator @ewarren has asked for information ...      1
# 37038  37038  Just commented on @thejournal_ie: Poll: Are yo...      0
# 37039  37039  My wife got laid off yesterday because the sma...      2
# 37040  37040  Humanity is doomed\r\r\n#coronavirus #coronacr...      0
#
#                                              Tweet_token  \
# 0      [gaisss, pleas, read, pleas, limit, go, outsid...
# 1      [today, week, lockdown, lot, confectionari, st...
# 2      [tuski, partner, amref, provid, ground, health...
# 3      [u, ur, groceri, shop, like, regular, person, ...
# 4      [uk, critic, care, nurs, cri, empti, supermark...
# ...                                                  ...
# 37036  [minnesota, classifi, groceri, store, worker, ...
# 37037  [us, senat, ask, inform, leveragedloan, price,...
# 37038  [comment, poll, onlin, shop, normal, covid, 19...
# 37039  [wife, got, laid, yesterday, small, retail, st...
# 37040  [human, doom, coronaviru, coronacrisi, toiletp...
#
#                                                    tweet
# 0      gaisss pleas read pleas limit go outsid pleas ...
# 1      today week lockdown lot confectionari store ru...
# 2      tuski partner amref provid ground health educ ...
# 3      u ur groceri shop like regular person u still ...
# 4      uk critic care nurs cri empti supermarket shel...
# ...                                                  ...
# 37036  minnesota classifi groceri store worker emerg ...
# 37037  us senat ask inform leveragedloan price debt f...
# 37038     comment poll onlin shop normal covid 19 crisi
# 37039  wife got laid yesterday small retail store wor...
# 37040  human doom coronaviru coronacrisi toiletpap to...
#
# [37041 rows x 5 columns]

# %%
def f(x):
    res = ""
    for word in x:
        res+=word
        res+=" "
    return res
X = X.map(lambda x : f(x))

def get_max_length(text):
    """
    get max token counts
    """
    max_length = 0
    for row in text['tweet']:
        if len(row.split(" ")) > max_length:
            max_length = len(row.split(" "))
    return max_length

def get_word2vec_enc(tweets):
    """
    get word2vec value
    """
    encoded_tweets = []
    for tweet in tweets:
#         tokens = tweet.split(" ")
        word2vec_embedding = embed(tweet)
        encoded_tweets.append(word2vec_embedding)
    return encoded_tweets
        
def get_padded_encoded_tweets(encoded_tweets):
    """
    zero padding
    """
    padded_tweets_encoding = []
    for enc_tweet in encoded_tweets:
        zero_padding_cnt = max_length - enc_tweet.shape[0]
        pad = np.zeros((1, 128))
        for i in range(zero_padding_cnt):
            enc_tweet = np.concatenate((pad, enc_tweet), axis=0)
        padded_tweets_encoding.append(enc_tweet)
    return padded_tweets_encoding

def label_encode(label):
    """
    one hot encoding
    """
    if label == 0:
        return [1,0,0,0,0]
    elif label == 1:
        return [0,1,0,0,0]
    elif label == 2:
        return [0,0,1,0,0]
    elif label == 3:
        return [0,0,0,1,0]
    elif label == 4:
        return [0,0,0,0,1]
    
def preprocess(text):
    """
    encode text value to numeric value
    """
    # encode words into word2vec
    tweets = text['Tweet_token'].tolist()
    
    encoded_tweets = get_word2vec_enc(tweets)
    padded_encoded_tweets = get_padded_encoded_tweets(encoded_tweets)
    # encoded label
    labels = text['Label'].tolist()
    encoded_label = [label_encode(label) for label in labels]
    X = np.array(padded_encoded_tweets)
    Y = np.array(encoded_label)
    return X, Y

# %%
text
# Out:
#           Id                                              Tweet  Label  \
# 0          0  https://t.co/UpjxfOgQs8\r\r\n\r\r\nGaisss! Ple...      4
# 1          1  @mygovindia Today just after a week of lockdow...      1
# 2          2  Tuskys partners with Amref to provide on groun...      2
# 3          3  @chrissyteigen are u doing ur own grocery shop...      1
# 4          4  UK Critical Care Nurse Cries at Empty SuperMar...      0
# ...      ...                                                ...    ...
# 37036  37036  Minnesota classifies grocery store workers as ...      1
# 37037  37037  US Senator @ewarren has asked for information ...      1
# 37038  37038  Just commented on @thejournal_ie: Poll: Are yo...      0
# 37039  37039  My wife got laid off yesterday because the sma...      2
# 37040  37040  Humanity is doomed\r\r\n#coronavirus #coronacr...      0
#
#                                              Tweet_token  \
# 0      [gaisss, pleas, read, pleas, limit, go, outsid...
# 1      [today, week, lockdown, lot, confectionari, st...
# 2      [tuski, partner, amref, provid, ground, health...
# 3      [u, ur, groceri, shop, like, regular, person, ...
# 4      [uk, critic, care, nurs, cri, empti, supermark...
# ...                                                  ...
# 37036  [minnesota, classifi, groceri, store, worker, ...
# 37037  [us, senat, ask, inform, leveragedloan, price,...
# 37038  [comment, poll, onlin, shop, normal, covid, 19...
# 37039  [wife, got, laid, yesterday, small, retail, st...
# 37040  [human, doom, coronaviru, coronacrisi, toiletp...
#
#                                                    tweet
# 0      gaisss pleas read pleas limit go outsid pleas ...
# 1      today week lockdown lot confectionari store ru...
# 2      tuski partner amref provid ground health educ ...
# 3      u ur groceri shop like regular person u still ...
# 4      uk critic care nurs cri empti supermarket shel...
# ...                                                  ...
# 37036  minnesota classifi groceri store worker emerg ...
# 37037  us senat ask inform leveragedloan price debt f...
# 37038     comment poll onlin shop normal covid 19 crisi
# 37039  wife got laid yesterday small retail store wor...
# 37040  human doom coronaviru coronacrisi toiletpap to...
#
# [37041 rows x 5 columns]

# %%
text["tweet"] = text["Tweet_token"].apply(f)
max_length = get_max_length(text)
max_length
# Out:
# 68

# %%
text
# Out:
#           Id                                              Tweet  Label  \
# 0          0  https://t.co/UpjxfOgQs8\r\r\n\r\r\nGaisss! Ple...      4
# 1          1  @mygovindia Today just after a week of lockdow...      1
# 2          2  Tuskys partners with Amref to provide on groun...      2
# 3          3  @chrissyteigen are u doing ur own grocery shop...      1
# 4          4  UK Critical Care Nurse Cries at Empty SuperMar...      0
# ...      ...                                                ...    ...
# 37036  37036  Minnesota classifies grocery store workers as ...      1
# 37037  37037  US Senator @ewarren has asked for information ...      1
# 37038  37038  Just commented on @thejournal_ie: Poll: Are yo...      0
# 37039  37039  My wife got laid off yesterday because the sma...      2
# 37040  37040  Humanity is doomed\r\r\n#coronavirus #coronacr...      0
#
#                                              Tweet_token  \
# 0      [gaisss, pleas, read, pleas, limit, go, outsid...
# 1      [today, week, lockdown, lot, confectionari, st...
# 2      [tuski, partner, amref, provid, ground, health...
# 3      [u, ur, groceri, shop, like, regular, person, ...
# 4      [uk, critic, care, nurs, cri, empti, supermark...
# ...                                                  ...
# 37036  [minnesota, classifi, groceri, store, worker, ...
# 37037  [us, senat, ask, inform, leveragedloan, price,...
# 37038  [comment, poll, onlin, shop, normal, covid, 19...
# 37039  [wife, got, laid, yesterday, small, retail, st...
# 37040  [human, doom, coronaviru, coronacrisi, toiletp...
#
#                                                    tweet
# 0      gaisss pleas read pleas limit go outsid pleas ...
# 1      today week lockdown lot confectionari store ru...
# 2      tuski partner amref provid ground health educ ...
# 3      u ur groceri shop like regular person u still ...
# 4      uk critic care nurs cri empti supermarket shel...
# ...                                                  ...
# 37036  minnesota classifi groceri store worker emerg ...
# 37037  us senat ask inform leveragedloan price debt f...
# 37038     comment poll onlin shop normal covid 19 crisi
# 37039  wife got laid yesterday small retail store wor...
# 37040  human doom coronaviru coronacrisi toiletpap to...
#
# [37041 rows x 5 columns]

# %%
test = text.sample(frac = 0.3, random_state =1)
train = text[~text.index.isin(list(test.index))]
val = test.sample(frac = 0.5, random_state = 1)
test = test[~test.index.isin(list(val.index))]

# %%
max_length = get_max_length(train)
max_length
# Out:
# 68

# %%
train_X, train_Y = preprocess(train)
val_X, val_Y = preprocess(val)
test_X, test_Y = preprocess(test)

# %%
# LSTM model
model = Sequential()
model.add(LSTM(32))
model.add(Dense(5, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %% [markdown]
# ## Train

# %%
print('Train...')
model.fit(train_X, train_Y,epochs=40, verbose = 1, validation_data=(val_X, val_Y))
# Out:
# Train...
# Epoch 1/40
# 811/811 [==============================] - 19s 21ms/step - loss: 1.4643 - accuracy: 0.3423 - val_loss: 1.2681 - val_accuracy: 0.4478
# Epoch 2/40
# 811/811 [==============================] - 20s 25ms/step - loss: 1.2383 - accuracy: 0.4712 - val_loss: 1.2261 - val_accuracy: 0.4739
# Epoch 3/40
# 811/811 [==============================] - 22s 27ms/step - loss: 1.1667 - accuracy: 0.5042 - val_loss: 1.1913 - val_accuracy: 0.4919
# Epoch 4/40
# 811/811 [==============================] - 22s 27ms/step - loss: 1.1381 - accuracy: 0.5247 - val_loss: 1.1531 - val_accuracy: 0.5164
# Epoch 5/40
# 811/811 [==============================] - 22s 27ms/step - loss: 1.1042 - accuracy: 0.5394 - val_loss: 1.1380 - val_accuracy: 0.5265
# Epoch 6/40
# 811/811 [==============================] - 22s 28ms/step - loss: 1.0883 - accuracy: 0.5457 - val_loss: 1.1512 - val_accuracy: 0.5164
# Epoch 7/40
# 811/811 [==============================] - 23s 28ms/step - loss: 1.0656 - accuracy: 0.5555 - val_loss: 1.1230 - val_accuracy: 0.5355
# Epoch 8/40
# 811/811 [==============================] - 23s 28ms/step - loss: 1.0397 - accuracy: 0.5750 - val_loss: 1.1077 - val_accuracy: 0.5446
# Epoch 9/40
# 811/811 [==============================] - 23s 29ms/step - loss: 1.0281 - accuracy: 0.5816 - val_loss: 1.1237 - val_accuracy: 0.5362
# Epoch 10/40
# 811/811 [==============================] - 24s 29ms/step - loss: 1.0307 - accuracy: 0.5765 - val_loss: 1.1036 - val_accuracy: 0.5466
# Epoch 11/40
# 811/811 [==============================] - 23s 28ms/step - loss: 1.0061 - accuracy: 0.5904 - val_loss: 1.0936 - val_accuracy: 0.5567
# Epoch 12/40
# 811/811 [==============================] - 23s 28ms/step - loss: 0.9944 - accuracy: 0.5978 - val_loss: 1.0907 - val_accuracy: 0.5580
# Epoch 13/40
# 811/811 [==============================] - 23s 28ms/step - loss: 0.9749 - accuracy: 0.6120 - val_loss: 1.0974 - val_accuracy: 0.5590
# Epoch 14/40
# 811/811 [==============================] - 23s 28ms/step - loss: 0.9702 - accuracy: 0.6124 - val_loss: 1.0887 - val_accuracy: 0.5626
# Epoch 15/40
# 811/811 [==============================] - 23s 28ms/step - loss: 0.9466 - accuracy: 0.6239 - val_loss: 1.0967 - val_accuracy: 0.5632
# Epoch 16/40
# 811/811 [==============================] - 22s 28ms/step - loss: 0.9319 - accuracy: 0.6328 - val_loss: 1.0857 - val_accuracy: 0.5648
# Epoch 17/40
# 811/811 [==============================] - 22s 27ms/step - loss: 0.9208 - accuracy: 0.6333 - val_loss: 1.0829 - val_accuracy: 0.5709
# Epoch 18/40
# 811/811 [==============================] - 22s 27ms/step - loss: 0.9183 - accuracy: 0.6340 - val_loss: 1.0854 - val_accuracy: 0.5679
# Epoch 19/40
# 811/811 [==============================] - 22s 27ms/step - loss: 0.8923 - accuracy: 0.6485 - val_loss: 1.0857 - val_accuracy: 0.5608
# Epoch 20/40
# 811/811 [==============================] - 22s 28ms/step - loss: 0.8841 - accuracy: 0.6561 - val_loss: 1.0838 - val_accuracy: 0.5704
# Epoch 21/40
# 811/811 [==============================] - 21s 26ms/step - loss: 0.8874 - accuracy: 0.6520 - val_loss: 1.1196 - val_accuracy: 0.5553
# Epoch 22/40
# 811/811 [==============================] - 22s 27ms/step - loss: 0.8767 - accuracy: 0.6545 - val_loss: 1.0908 - val_accuracy: 0.5715
# Epoch 23/40
# 811/811 [==============================] - 22s 28ms/step - loss: 0.8466 - accuracy: 0.6671 - val_loss: 1.1047 - val_accuracy: 0.5765
# Epoch 24/40
# 811/811 [==============================] - 21s 26ms/step - loss: 0.8502 - accuracy: 0.6704 - val_loss: 1.1034 - val_accuracy: 0.5695
# Epoch 25/40
# 811/811 [==============================] - 21s 26ms/step - loss: 0.8282 - accuracy: 0.6806 - val_loss: 1.1461 - val_accuracy: 0.5616
# Epoch 26/40
# 811/811 [==============================] - 21s 25ms/step - loss: 0.8256 - accuracy: 0.6798 - val_loss: 1.0960 - val_accuracy: 0.5713
# Epoch 27/40
# 811/811 [==============================] - 20s 25ms/step - loss: 0.8125 - accuracy: 0.6892 - val_loss: 1.1280 - val_accuracy: 0.5725
# Epoch 28/40
# 811/811 [==============================] - 20s 25ms/step - loss: 0.7978 - accuracy: 0.6891 - val_loss: 1.1015 - val_accuracy: 0.5734
# Epoch 29/40
# 811/811 [==============================] - 21s 26ms/step - loss: 0.7858 - accuracy: 0.6957 - val_loss: 1.1121 - val_accuracy: 0.5742
# Epoch 30/40
# 811/811 [==============================] - 20s 25ms/step - loss: 0.7883 - accuracy: 0.7019 - val_loss: 1.1299 - val_accuracy: 0.5617
# Epoch 31/40
# 811/811 [==============================] - 21s 25ms/step - loss: 0.7725 - accuracy: 0.7107 - val_loss: 1.1121 - val_accuracy: 0.5693
# Epoch 32/40
# 811/811 [==============================] - 21s 26ms/step - loss: 0.7521 - accuracy: 0.7153 - val_loss: 1.1323 - val_accuracy: 0.5677
# Epoch 33/40
# 811/811 [==============================] - 20s 25ms/step - loss: 0.7391 - accuracy: 0.7231 - val_loss: 1.1457 - val_accuracy: 0.5763
# Epoch 34/40
# 811/811 [==============================] - 20s 25ms/step - loss: 0.7365 - accuracy: 0.7225 - val_loss: 1.1613 - val_accuracy: 0.5673
# Epoch 35/40
# 811/811 [==============================] - 20s 25ms/step - loss: 0.7329 - accuracy: 0.7230 - val_loss: 1.1597 - val_accuracy: 0.5612
# Epoch 36/40
# 811/811 [==============================] - 20s 25ms/step - loss: 0.7278 - accuracy: 0.7258 - val_loss: 1.1716 - val_accuracy: 0.5711
# Epoch 37/40
# 811/811 [==============================] - 21s 25ms/step - loss: 0.7085 - accuracy: 0.7381 - val_loss: 1.1828 - val_accuracy: 0.5641
# Epoch 38/40
# 811/811 [==============================] - 21s 26ms/step - loss: 0.7083 - accuracy: 0.7404 - val_loss: 1.1994 - val_accuracy: 0.5711
# Epoch 39/40
# 811/811 [==============================] - 21s 26ms/step - loss: 0.6898 - accuracy: 0.7405 - val_loss: 1.1972 - val_accuracy: 0.5628
# Epoch 40/40
# 811/811 [==============================] - 20s 25ms/step - loss: 0.6825 - accuracy: 0.7449 - val_loss: 1.2054 - val_accuracy: 0.5779

# %%
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_10 (LSTM)               (None, 32)                20608
# _________________________________________________________________
# dense_11 (Dense)             (None, 5)                 165
# =================================================================
# Total params: 20,773
# Trainable params: 20,773
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.save('model_LSTM')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_10_layer_call_and_return_conditional_losses, lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses, lstm_cell_10_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as lstm_cell_10_layer_call_and_return_conditional_losses, lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses, lstm_cell_10_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model_LSTM/assets
# INFO:tensorflow:Assets written to: model_LSTM/assets

# %% [markdown]
# ### Measure Performance

# %%
score, acc = model.evaluate(test_X, test_Y, verbose=2)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# 174/174 - 1s - loss: 1.1445 - accuracy: 0.5907
# Test score: 1.1444698572158813
# Test accuracy: 0.5907127261161804

# %% [markdown]
# ### Prediction

# %%
pred_y = model.predict(test_X)

pred_y = [np.argmax(y) for y in pred_y]

test_y = [np.argmax(y) for y in test_Y]

# %%
accuracy =accuracy_score(test_y, pred_y)
f1score = f1_score(test_y, pred_y, average='macro')
precision = precision_score(test_y, pred_y, average='macro')
recall = recall_score(test_y, pred_y, average='macro')

# %%
## score of the model
print("Accuracy : ",accuracy)
print("Precision : ",precision)
print("Recall : ", recall)
print("F1 score : ", f1score)
# Out:
# Accuracy :  0.5907127429805615
# Precision :  0.616731057688326
# Recall :  0.5938277854491208
# F1 score :  0.6032540941733647

# %% [markdown]
# ### Confusion Matrix and heat map

# %%
cm = confusion_matrix(test_y, pred_y)
cm
# Out:
# array([[436, 268,  13,  24,   5],
#        [161, 807, 134, 224,  36],
#        [ 18, 163, 666, 187,   9],
#        [ 35, 307, 153, 842, 182],
#        [  6,  45,  18, 286, 531]])

# %%
fig = sns.heatmap(cm, cmap = 'Blues', annot=True)
fig.set(xlabel='y_pred', ylabel='y_ture')
# Out:
# [Text(33.0, 0.5, 'y_ture'), Text(0.5, 15.0, 'y_pred')]

# %%
#https://colab.research.google.com/github/minsuk-heo/tf2/blob/master/jupyter_notebooks/10.Word2Vec_LSTM.ipynb#scrollTo=915WJfpKp9H_
